# %% [markdown]
# ## Introduction
#
# The data for this project is pulled from the Boston Blue Bikes [website](https://www.bluebikes.com/system-data). The data is being pulled from the historical data page, where there are shown to be several file naming conventions over the past decade. This corresponds to changes in the physical infrastructure (expansion of bike stations, etc) and changes in the organizational structures (Hubway to Boston Blue Bikes).
#
# We need to verify if these naming conventions also apply to changes in the file structures, so that we can adjust the dataframes before uploading to GCP.
#
# ## File types
#
# There are two main subsets of data files available in this directory: trip data and station data.
#
# ### Trip data
#
# The trip data files follow three naming conventions:
# - hubway_Trips_YYYY.zip
# - YYYYMM-hubway-tripdata.zip
# - YYYYMM-bluebikes-tripdata.zip
#
# ### Station data
#
# The station data is separated into four files, each with a different naming convention. To verify the integrity, each will be explored.

# %% [markdown]
# ## Trip Data

# %% [markdown]
# ### hubway_Trips_YYYY.zip
#
# These compressed files contain a single csv file, and so that can be opened with the pandas.read_csv() method.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://s3.amazonaws.com/hubway-data/hubway_Trips_2011.csv")
df.head(10)
# Out:
# /tmp/ipykernel_91127/327739768.py:4: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("https://s3.amazonaws.com/hubway-data/hubway_Trips_2011.csv")
#    Duration        Start date          End date Start station number  \
# 0   1712320  11/30/2011 23:58    12/1/2011 0:26               D32005
# 1    313200  11/30/2011 23:56    12/1/2011 0:01               C32008
# 2   1111430  11/30/2011 23:18  11/30/2011 23:36               A32009
# 3   1313487  11/30/2011 23:15  11/30/2011 23:37               A32001
# 4    345115  11/30/2011 22:59  11/30/2011 23:05               B32008
# 5    904843  11/30/2011 22:48  11/30/2011 23:03               A32004
# 6    266305  11/30/2011 22:42  11/30/2011 22:47               D32005
# 7   2065156  11/30/2011 22:40  11/30/2011 23:14               D32005
# 8   2093619  11/30/2011 22:39  11/30/2011 23:14               D32005
# 9    210672  11/30/2011 21:57  11/30/2011 22:00               D32011
#
#                               Start station name End station number  \
# 0       Boston Public Library - 700 Boylston St.             D32011
# 1                          Boylston at Fairfield             D32011
# 2                       Tremont St / W Newton St             D32006
# 3  Union Square - Brighton Ave. at Cambridge St.             D32005
# 4           Mayor Martin J. Walsh - 28 State St.             D32006
# 5                       Longwood Ave / Binney St             A32009
# 6       Boston Public Library - 700 Boylston St.             C32000
# 7       Boston Public Library - 700 Boylston St.             D32014
# 8       Boston Public Library - 700 Boylston St.             D32014
# 9                      Stuart St. at Charles St.             C32000
#
#                            End station name Bike number Member type Zip code  \
# 0                 Stuart St. at Charles St.      B00056      Member     2116
# 1                 Stuart St. at Charles St.      B00133      Casual      NaN
# 2               Lewis Wharf - Atlantic Ave.      B00471      Member     2109
# 3  Boston Public Library - 700 Boylston St.      B00056      Member     2116
# 4               Lewis Wharf - Atlantic Ave.      B00174      Member     2109
# 5                  Tremont St / W Newton St      B00203      Member     2118
# 6               Tremont St. at Berkeley St.      B00431      Member     2118
# 7                      Tremont St / West St      B00028      Member     2114
# 8                      Tremont St / West St      B00394      Member     2111
# 9               Tremont St. at Berkeley St.      B00381      Member     2116
#
#    Gender
# 0    Male
# 1     NaN
# 2    Male
# 3    Male
# 4    Male
# 5    Male
# 6    Male
# 7  Female
# 8    Male
# 9  Female

# %%
def clean_tripdata_old(df: pd.DataFrame) -> pd.DataFrame:
    """All columns need to be renamed and retyped to match newer trips datasets"""

    # tripduration
    df["tripduration"] = df["Duration"]
    df["tripduration"] = pd.to_numeric(df["tripduration"], downcast="integer")
    df = df.drop(["Duration"], axis=1)
    df = df[df["tripduration"] < 4.32e5]

    # starttime
    df["starttime"] = df["Start date"]
    df["starttime"] = pd.to_datetime(df["starttime"])
    df = df.drop(["Start date"], axis=1)

    # stoptime
    df["stoptime"] = df["End date"]
    df["stoptime"] = pd.to_datetime(df["stoptime"])
    df = df.drop(["End date"], axis=1)

    # start station id
    df["start station id"] = df["Start station number"]
    df = df.drop(["Start station number"], axis=1)

    # start station name
    df["start station name"] = df["Start station name"].str.lower()
    df = df.drop(["Start station name"], axis=1)

    # start station latitude
    df["start station latitude"] = np.nan

    # start station longitude
    df["start station longitude"] = np.nan

    # end station id
    df["end station id"] = df["End station number"]
    df = df.drop(["End station number"], axis=1)

    # end station name
    df["end station name"] = df["End station name"].str.lower()
    df = df.drop(["End station name"], axis=1)

    # end station latitude
    df["end station latitude"] = np.nan

    # end station longitude
    df["end station longitude"] = np.nan

    # bikeid
    df["bikeid"] = df["Bike number"]
    df = df.drop(["Bike number"], axis=1)

    # usertype
    df["usertype"] = df["Member type"].str.lower()
    df = df.drop(["Member type"], axis=1)

    # Zip code

    df["postal code"] = df["Zip code"].astype(str)
    df = df.drop(["Zip code"], axis=1)

    df["postal code"] = pd.to_numeric(
        df["postal code"], downcast="integer", errors="coerce"
    )

    # birth year
    df["birth year"] = np.nan

    # gender
    df["gender"] = df["Gender"]
    df.loc[(df["gender"] != "Male") & (df["gender"] != "Female"), "gender"] = 0
    df.loc[df["gender"] == "Male", "gender"] = 1
    df.loc[df["gender"] == "Female", "gender"] = 2
    df["gender"] = pd.to_numeric(df["gender"], downcast="float")
    df = df.drop(["Gender"], axis=1)

    return df

cleaned_df = clean_tripdata_old(df)
cleaned_df.head()
# Out:
#     tripduration           starttime            stoptime start station id  \
# 1         313200 2011-11-30 23:56:00 2011-12-01 00:01:00           C32008
# 4         345115 2011-11-30 22:59:00 2011-11-30 23:05:00           B32008
# 6         266305 2011-11-30 22:42:00 2011-11-30 22:47:00           D32005
# 9         210672 2011-11-30 21:57:00 2011-11-30 22:00:00           D32011
# 11        410857 2011-11-30 21:41:00 2011-11-30 21:47:00           A32010
#
#                           start station name  start station latitude  \
# 1                      boylston at fairfield                     NaN
# 4       mayor martin j. walsh - 28 state st.                     NaN
# 6   boston public library - 700 boylston st.                     NaN
# 9                  stuart st. at charles st.                     NaN
# 11         south station - 700 atlantic ave.                     NaN
#
#     start station longitude end station id  \
# 1                       NaN         D32011
# 4                       NaN         D32006
# 6                       NaN         C32000
# 9                       NaN         C32000
# 11                      NaN         D32017
#
#                                end station name  end station latitude  \
# 1                     stuart st. at charles st.                   NaN
# 4                   lewis wharf - atlantic ave.                   NaN
# 6                   tremont st. at berkeley st.                   NaN
# 9                   tremont st. at berkeley st.                   NaN
# 11  the esplanade - beacon st. at arlington st.                   NaN
#
#     end station longitude  bikeid usertype  postal code  birth year  gender
# 1                     NaN  B00133   casual          NaN         NaN     0.0
# 4                     NaN  B00174   member       2109.0         NaN     1.0
# 6                     NaN  B00431   member       2118.0         NaN     1.0
# 9                     NaN  B00381   member       2116.0         NaN     2.0
# 11                    NaN  B00241   member       2116.0         NaN     1.0

# %%
print(cleaned_df.dtypes)
print("\n")
print(cleaned_df.shape)
print("\n")
cleaned_df.describe()
# Out:
# tripduration                        int32
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                   object
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                     object
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                             object
# usertype                           object
# postal code                       float64
# birth year                        float64
# gender                            float32
# dtype: object
#
#
# (35272, 16)
#         tripduration  start station latitude  start station longitude  \
# count   35272.000000                     0.0                      0.0
# mean   300279.423169                     NaN                      NaN
# std     85441.388165                     NaN                      NaN
# min     60021.000000                     NaN                      NaN
# 25%    237282.500000                     NaN                      NaN
# 50%    309973.000000                     NaN                      NaN
# 75%    372441.000000                     NaN                      NaN
# max    431999.000000                     NaN                      NaN
#
#        end station latitude  end station longitude   postal code  birth year  \
# count                   0.0                    0.0  29552.000000         0.0
# mean                    NaN                    NaN   2260.768848         NaN
# std                     NaN                    NaN   2473.133709         NaN
# min                     NaN                    NaN    216.000000         NaN
# 25%                     NaN                    NaN   2109.000000         NaN
# 50%                     NaN                    NaN   2118.000000         NaN
# 75%                     NaN                    NaN   2176.000000         NaN
# max                     NaN                    NaN  84010.000000         NaN
#
#              gender
# count  35272.000000
# mean       0.979190
# std        0.550547
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000

# %% [markdown]
# ### Files named YYYYMM-hubway-tripdata.zip
#
# These compressed files contain a single csv file, and so that can be opened with the pandas.read_csv() method.

# %%
import pandas as pd

df = pd.read_csv("https://s3.amazonaws.com/hubway-data/201501-hubway-tripdata.zip")
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           542  2015-01-01 00:21:44  2015-01-01 00:30:47               115
# 1           438  2015-01-01 00:27:03  2015-01-01 00:34:21                80
# 2           254  2015-01-01 00:31:31  2015-01-01 00:35:46                91
# 3           432  2015-01-01 00:53:46  2015-01-01 01:00:58               115
# 4           735  2015-01-01 01:07:06  2015-01-01 01:19:21               105
#
#                                  start station name  start station latitude  \
# 0                             Porter Square Station               42.387995
# 1           MIT Stata Center at Vassar St / Main St               42.361962
# 2  One Kendall Square at Hampshire St / Portland St               42.366277
# 3                             Porter Square Station               42.387995
# 4   Lower Cambridgeport at Magazine St/Riverside Rd               42.356954
#
#    start station longitude  end station id  \
# 0               -71.119084              96
# 1               -71.092053              95
# 2               -71.091690              68
# 3               -71.119084              96
# 4               -71.113687              88
#
#                                     end station name  end station latitude  \
# 0  Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 1        Cambridge St - at Columbia St / Webster Ave             42.372969
# 2              Central Square at Mass Ave / Essex St             42.365070
# 3  Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 4      Inman Square at Vellucci Plaza / Hampshire St             42.374035
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -71.111075     277  Subscriber       1984       1
# 1             -71.094445     648  Subscriber       1985       1
# 2             -71.103100     555  Subscriber       1974       1
# 3             -71.111075    1307  Subscriber       1987       1
# 4             -71.101427     177    Customer       1986       2

# %%
def clean_tripdata_new(df: pd.DataFrame) -> pd.DataFrame:
    """Columns retyped to increase performance"""

    # tripduration
    df["tripduration"] = pd.to_numeric(df["tripduration"], downcast="integer")
    df = df[df["tripduration"] < 4.32e5]

    # starttime
    df["starttime"] = pd.to_datetime(df["starttime"])

    # stoptime
    df["stoptime"] = pd.to_datetime(df["stoptime"])

    # start_station_id
    df["start_station_id"] = df["start station id"].astype(str)
    df = df.drop(["start station id"], axis=1)

    # start_station_name
    df["start_station_name"] = df["start station name"].astype(str)
    df["start_station_name"] = df["start_station_name"].str.lower()
    df = df.drop(["start station name"], axis=1)

    # start_station_latitude
    df["start_station_latitude"] = pd.to_numeric(
        df["start station latitude"], downcast="float"
    )
    df = df.drop(["start station latitude"], axis=1)

    # start_station_longitude
    df["start_station_longitude"] = pd.to_numeric(
        df["start station longitude"], downcast="float"
    )
    df = df.drop(["start station longitude"], axis=1)

    # end_station_id
    df["end_station_id"] = df["end station id"].astype(str)
    df = df.drop(["end station id"], axis=1)

    # end_station_name
    df["end_station_name"] = df["end station name"].astype(str)
    df["end_station_name"] = df["end_station_name"].str.lower()
    df = df.drop(["end station name"], axis=1)

    # end_station_latitude
    df.loc[df["end station latitude"] == r"\N", "end station latitude"] = np.nan
    df["end_station_latitude"] = pd.to_numeric(
        df["end station latitude"], downcast="float"
    )
    df = df.drop(["end station latitude"], axis=1)

    # end_station_longitude
    df.loc[df["end station longitude"] == r"\N", "end station longitude"] = np.nan
    df["end_station_longitude"] = pd.to_numeric(
        df["end station longitude"], downcast="float"
    )
    df = df.drop(["end station longitude"], axis=1)

    # bikeid
    df["bikeid"] = df["bikeid"].astype(str)

    # usertype
    df["usertype"] = df["usertype"].astype(str)
    df["usertype"] = df["usertype"].str.lower()

    # birth_year
    if "birth year" in df:
        df["birth_year"] = df["birth year"]
        df.loc[df["birth_year"] == r"\N", "birth_year"] = np.nan
        df["birth_year"] = pd.to_numeric(df["birth_year"], downcast="float")
        df = df.drop(["birth year"], axis=1)
    else:
        df["birth_year"] = np.nan

    # gender
    if "gender" in df:
        df["gender"] = pd.to_numeric(df["gender"], downcast="integer")
    else:
        df["gender"] = 0

    # postal_code
    if "postal code" in df:
        df["postal_code"] = df["postal code"]
        df["postal_code"] = pd.to_numeric(
            df["postal_code"], downcast="float", errors="coerce"
        )
        df = df.drop(["postal code"], axis=1)
    else:
        df["postal_code"] = np.nan

    return df

cleaned_df = clean_tripdata_new(df)
cleaned_df.head()
# Out:
#    tripduration           starttime            stoptime bikeid    usertype  \
# 0           542 2015-01-01 00:21:44 2015-01-01 00:30:47    277  subscriber
# 1           438 2015-01-01 00:27:03 2015-01-01 00:34:21    648  subscriber
# 2           254 2015-01-01 00:31:31 2015-01-01 00:35:46    555  subscriber
# 3           432 2015-01-01 00:53:46 2015-01-01 01:00:58   1307  subscriber
# 4           735 2015-01-01 01:07:06 2015-01-01 01:19:21    177    customer
#
#    gender start_station_id                                start_station_name  \
# 0       1              115                             porter square station
# 1       1               80           mit stata center at vassar st / main st
# 2       1               91  one kendall square at hampshire st / portland st
# 3       1              115                             porter square station
# 4       2              105   lower cambridgeport at magazine st/riverside rd
#
#    start_station_latitude  start_station_longitude end_station_id  \
# 0               42.387997               -71.119087             96
# 1               42.361961               -71.092056             95
# 2               42.366276               -71.091690             68
# 3               42.387997               -71.119087             96
# 4               42.356953               -71.113686             88
#
#                                     end_station_name  end_station_latitude  \
# 0  cambridge main library at broadway / trowbridg...             42.373379
# 1        cambridge st - at columbia st / webster ave             42.372971
# 2              central square at mass ave / essex st             42.365070
# 3  cambridge main library at broadway / trowbridg...             42.373379
# 4      inman square at vellucci plaza / hampshire st             42.374035
#
#    end_station_longitude  birth_year  postal_code
# 0             -71.111076      1984.0          NaN
# 1             -71.094444      1985.0          NaN
# 2             -71.103104      1974.0          NaN
# 3             -71.111076      1987.0          NaN
# 4             -71.101425      1986.0          NaN

# %%
print(cleaned_df.isna().sum())
# Out:
# tripduration                  0
# starttime                     0
# stoptime                      0
# bikeid                        0
# usertype                      0
# gender                        0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# birth_year                  254
# postal_code                7840
# dtype: int64

# %%
print(df.dtypes)
print("\n")
print(df.shape)
print("\n")
df.describe()
# Out:
# tripduration                 int32
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                  object
# gender                       int64
# dtype: object
#
#
# (7840, 15)
#         tripduration  start station id  start station latitude  \
# count    7840.000000       7840.000000             7840.000000
# mean      647.878444         91.928954               42.369236
# std      3998.551965         19.303781                0.008205
# min        62.000000         67.000000               42.356954
# 25%       287.000000         75.000000               42.363465
# 50%       406.000000         89.500000               42.366621
# 75%       602.000000        107.000000               42.373268
# max    232319.000000        145.000000               42.397828
#
#        start station longitude  end station id  end station latitude  \
# count              7840.000000     7840.000000           7840.000000
# mean                -71.102210       90.985459             42.368961
# std                   0.014306       20.584012              0.008531
# min                 -71.139459        1.000000             42.334876
# 25%                 -71.114214       74.000000             42.362613
# 50%                 -71.101427       89.000000             42.366621
# 75%                 -71.091690      107.000000             42.373268
# max                 -71.069957      149.000000             42.397828
#
#        end station longitude       bikeid       gender
# count            7840.000000  7840.000000  7840.000000
# mean              -71.102134   932.269515     1.211735
# std                 0.014827   216.461422     0.481382
# min               -71.139459    23.000000     0.000000
# 25%               -71.114214   748.000000     1.000000
# 50%               -71.101427   894.000000     1.000000
# 75%               -71.091690  1090.000000     1.000000
# max               -71.048927  1325.000000     2.000000

# %% [markdown]
# ### Files named YYYYMM-bluebikes-tripdata.zip
#
# These compressed files contain a csv file and a subdirectory, so they need to be opened with requests, io and zipfile modules.

# %%
import pandas as pd
import requests
import zipfile
import io

url = "https://s3.amazonaws.com/hubway-data/201805-bluebikes-tripdata.zip"
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
df = pd.read_csv(z.open("201805-bluebikes-tripdata.csv"))
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1177  2018-05-01 00:01:32.4590  2018-05-01 00:21:10.0260
# 1           733  2018-05-01 00:05:19.4970  2018-05-01 00:17:32.7190
# 2           437  2018-05-01 00:05:37.7590  2018-05-01 00:12:54.8300
# 3           730  2018-05-01 00:05:39.6780  2018-05-01 00:17:50.5880
# 4           411  2018-05-01 00:06:10.1590  2018-05-01 00:13:02.0490
#
#    start station id                              start station name  \
# 0               184  Sidney Research Campus/ Erie Street at Waverly
# 1                67                    MIT at Mass Ave / Amherst St
# 2                54                           Tremont St at West St
# 3                54                           Tremont St at West St
# 4                54                           Tremont St at West St
#
#    start station latitude  start station longitude  end station id  \
# 0               42.357753               -71.103934             189
# 1               42.358100               -71.093198              41
# 2               42.354979               -71.063348               6
# 3               42.354979               -71.063348              46
# 4               42.354979               -71.063348               6
#
#                                     end station name  end station latitude  \
# 0                                          Kendall T             42.362428
# 1  Packard's Corner - Commonwealth Ave at Brighto...             42.352261
# 2                             Cambridge St at Joy St             42.361291
# 3  Christian Science Plaza - Massachusetts Ave at...             42.343666
# 4                             Cambridge St at Joy St             42.361291
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -71.084955     790  Subscriber        1994       1
# 1             -71.123831    1238  Subscriber        1993       2
# 2             -71.065262     218  Subscriber        1993       1
# 3             -71.085824    1885  Subscriber        1992       1
# 4             -71.065262     602    Customer        1969       0

# %%
cleaned_df = clean_tripdata_new(df)
cleaned_df.head()
# Out:
# /tmp/ipykernel_91127/4144987808.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["starttime"] = pd.to_datetime(df["starttime"])
# /tmp/ipykernel_91127/4144987808.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stoptime"] = pd.to_datetime(df["stoptime"])
# /tmp/ipykernel_91127/4144987808.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["start_station_id"] = df["start station id"].astype(str)
#    tripduration               starttime                stoptime bikeid  \
# 0          1177 2018-05-01 00:01:32.459 2018-05-01 00:21:10.026    790
# 1           733 2018-05-01 00:05:19.497 2018-05-01 00:17:32.719   1238
# 2           437 2018-05-01 00:05:37.759 2018-05-01 00:12:54.830    218
# 3           730 2018-05-01 00:05:39.678 2018-05-01 00:17:50.588   1885
# 4           411 2018-05-01 00:06:10.159 2018-05-01 00:13:02.049    602
#
#      usertype  gender start_station_id  \
# 0  subscriber       1              184
# 1  subscriber       2               67
# 2  subscriber       1               54
# 3  subscriber       1               54
# 4    customer       0               54
#
#                                start_station_name  start_station_latitude  \
# 0  sidney research campus/ erie street at waverly               42.357754
# 1                    mit at mass ave / amherst st               42.358101
# 2                           tremont st at west st               42.354980
# 3                           tremont st at west st               42.354980
# 4                           tremont st at west st               42.354980
#
#    start_station_longitude end_station_id  \
# 0               -71.103935            189
# 1               -71.093201             41
# 2               -71.063347              6
# 3               -71.063347             46
# 4               -71.063347              6
#
#                                     end_station_name  end_station_latitude  \
# 0                                          kendall t             42.362427
# 1  packard's corner - commonwealth ave at brighto...             42.352261
# 2                             cambridge st at joy st             42.361290
# 3  christian science plaza - massachusetts ave at...             42.343666
# 4                             cambridge st at joy st             42.361290
#
#    end_station_longitude  birth_year  postal_code
# 0             -71.084953      1994.0          NaN
# 1             -71.123833      1993.0          NaN
# 2             -71.065262      1993.0          NaN
# 3             -71.085823      1992.0          NaN
# 4             -71.065262      1969.0          NaN

# %%
print(cleaned_df.isna().sum())
# Out:
# tripduration                    0
# starttime                       0
# stoptime                        0
# bikeid                          0
# usertype                        0
# gender                          0
# start_station_id                0
# start_station_name              0
# start_station_latitude          0
# start_station_longitude         0
# end_station_id                  0
# end_station_name                0
# end_station_latitude            0
# end_station_longitude           0
# birth_year                      0
# postal_code                178831
# dtype: int64

# %%
print(cleaned_df.dtypes)
print("\n")
print(cleaned_df.shape)
print("\n")
df.describe()
# Out:
# tripduration                        int32
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# bikeid                             object
# usertype                           object
# gender                               int8
# start_station_id                   object
# start_station_name                 object
# start_station_latitude            float32
# start_station_longitude           float32
# end_station_id                     object
# end_station_name                   object
# end_station_latitude              float32
# end_station_longitude             float32
# birth_year                        float32
# postal_code                       float64
# dtype: object
#
#
# (178831, 16)
#        tripduration  start station id  start station latitude  \
# count  1.788650e+05     178865.000000           178865.000000
# mean   1.562178e+03         88.317245               42.357409
# std    4.329761e+04         58.560581                0.014519
# min    6.100000e+01          1.000000               42.303469
# 25%    4.280000e+02         43.000000               42.348717
# 50%    7.280000e+02         74.000000               42.358100
# 75%    1.207000e+03        124.000000               42.365673
# max    9.328558e+06        232.000000               42.406302
#
#        start station longitude  end station id  end station latitude  \
# count            178865.000000   178865.000000         178865.000000
# mean                -71.085090       88.505633             42.357379
# std                   0.025097       58.894745              0.014505
# min                 -71.166491        1.000000             42.303469
# 25%                 -71.103100       43.000000             42.348717
# 50%                 -71.085954       74.000000             42.357753
# 75%                 -71.064263      125.000000             42.365673
# max                 -71.006098      232.000000             42.406302
#
#        end station longitude        bikeid     birth year         gender
# count          178865.000000  178865.00000  178865.000000  178865.000000
# mean              -71.084767    1875.32903    1981.054818       1.064602
# std                 0.025142     952.57628      11.716032       0.603111
# min               -71.166491       1.00000    1887.000000       0.000000
# 25%               -71.103100    1030.00000    1969.000000       1.000000
# 50%               -71.085824    2108.00000    1984.000000       1.000000
# 75%               -71.064263    2661.00000    1991.000000       1.000000
# max               -71.006098    3306.00000    2002.000000       2.000000

# %%
import pandas as pd
import requests
import zipfile
import io

url = "https://s3.amazonaws.com/hubway-data/202105-bluebikes-tripdata.zip"
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
df = pd.read_csv(z.open("202105-bluebikes-tripdata.csv"))
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           609  2021-05-01 00:00:01.0450  2021-05-01 00:10:10.7300
# 1           632  2021-05-01 00:00:13.0880  2021-05-01 00:10:45.9060
# 2           187  2021-05-01 00:00:20.0430  2021-05-01 00:03:27.7480
# 3           976  2021-05-01 00:00:29.9290  2021-05-01 00:16:46.0470
# 4           136  2021-05-01 00:00:45.0970  2021-05-01 00:03:01.1520
#
#    start station id                                 start station name  \
# 0                66                      Commonwealth Ave at Griggs St
# 1               409                                 Elm St at White St
# 2                75  Lafayette Square at Mass Ave / Main St / Colum...
# 3               371                                      700 Huron Ave
# 4                39                        Washington St at Rutland St
#
#    start station latitude  start station longitude  end station id  \
# 0               42.349225               -71.132753             400
# 1               42.389524               -71.116941             104
# 2               42.363465               -71.100573             178
# 3               42.380788               -71.154129             455
# 4               42.338515               -71.074041              26
#
#                                     end station name  end station latitude  \
# 0                                   Lansdowne T Stop             42.347345
# 1  Harvard University Radcliffe Quadrangle at She...             42.380287
# 2                    MIT Pacific St at Purrington St             42.359573
# 3                                       Coolidge Sq.             42.372076
# 4                        Washington St at Waltham St             42.341575
#
#    end station longitude  bikeid    usertype postal code
# 0             -71.100168    4885  Subscriber       02134
# 1             -71.125107    3844  Subscriber       02144
# 2             -71.101295    6907  Subscriber       02139
# 3             -71.156831    2850  Subscriber       02138
# 4             -71.068904    3903  Subscriber       02143

# %%
cleaned_df = clean_tripdata_new(df)
cleaned_df.head()
# Out:
# /tmp/ipykernel_91127/4144987808.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["starttime"] = pd.to_datetime(df["starttime"])
# /tmp/ipykernel_91127/4144987808.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stoptime"] = pd.to_datetime(df["stoptime"])
# /tmp/ipykernel_91127/4144987808.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["start_station_id"] = df["start station id"].astype(str)
#    tripduration               starttime                stoptime bikeid  \
# 0           609 2021-05-01 00:00:01.045 2021-05-01 00:10:10.730   4885
# 1           632 2021-05-01 00:00:13.088 2021-05-01 00:10:45.906   3844
# 2           187 2021-05-01 00:00:20.043 2021-05-01 00:03:27.748   6907
# 3           976 2021-05-01 00:00:29.929 2021-05-01 00:16:46.047   2850
# 4           136 2021-05-01 00:00:45.097 2021-05-01 00:03:01.152   3903
#
#      usertype start_station_id  \
# 0  subscriber               66
# 1  subscriber              409
# 2  subscriber               75
# 3  subscriber              371
# 4  subscriber               39
#
#                                   start_station_name  start_station_latitude  \
# 0                      commonwealth ave at griggs st               42.349224
# 1                                 elm st at white st               42.389523
# 2  lafayette square at mass ave / main st / colum...               42.363464
# 3                                      700 huron ave               42.380787
# 4                        washington st at rutland st               42.338516
#
#    start_station_longitude end_station_id  \
# 0               -71.132751            400
# 1               -71.116943            104
# 2               -71.100571            178
# 3               -71.154129            455
# 4               -71.074043             26
#
#                                     end_station_name  end_station_latitude  \
# 0                                   lansdowne t stop             42.347343
# 1  harvard university radcliffe quadrangle at she...             42.380287
# 2                    mit pacific st at purrington st             42.359573
# 3                                       coolidge sq.             42.372078
# 4                        washington st at waltham st             42.341576
#
#    end_station_longitude  birth_year  gender  postal_code
# 0             -71.100166         NaN       0       2134.0
# 1             -71.125107         NaN       0       2144.0
# 2             -71.101295         NaN       0       2139.0
# 3             -71.156830         NaN       0       2138.0
# 4             -71.068901         NaN       0       2143.0

# %%
print(cleaned_df.dtypes)
print("\n")
print(cleaned_df.shape)
print("\n")
df.describe()
# Out:
# tripduration                        int32
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# bikeid                             object
# usertype                           object
# start_station_id                   object
# start_station_name                 object
# start_station_latitude            float32
# start_station_longitude           float32
# end_station_id                     object
# end_station_name                   object
# end_station_latitude              float32
# end_station_longitude             float32
# birth_year                        float64
# gender                              int64
# postal_code                       float64
# dtype: object
#
#
# (270764, 16)
#        tripduration  start station id  start station latitude  \
# count  2.708930e+05     270893.000000           270893.000000
# mean   1.947888e+03        170.271834               42.356854
# std    2.659677e+04        143.454280                0.017207
# min    6.100000e+01          1.000000               42.267902
# 25%    4.810000e+02         58.000000               42.347406
# 50%    8.250000e+02        112.000000               42.357219
# 75%    1.422000e+03        318.000000               42.365673
# max    3.366392e+06        510.000000               42.416085
#
#        start station longitude  end station id  end station latitude  \
# count            270893.000000   270893.000000         270893.000000
# mean                -71.088623      168.823484             42.356766
# std                   0.027101      143.239403              0.017321
# min                 -71.226275        1.000000             42.267902
# 25%                 -71.105495       57.000000             42.347406
# 50%                 -71.088220      108.000000             42.357143
# 75%                 -71.069750      296.000000             42.365673
# max                 -71.006098      510.000000             42.416085
#
#        end station longitude         bikeid
# count          270893.000000  270893.000000
# mean              -71.088430    4706.088349
# std                 0.027126    1492.641299
# min               -71.226275     218.000000
# 25%               -71.105495    3424.000000
# 50%               -71.088220    4882.000000
# 75%               -71.069616    6025.000000
# max               -71.006098    7029.000000
